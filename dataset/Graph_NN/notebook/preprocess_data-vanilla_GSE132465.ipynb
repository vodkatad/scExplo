# %%
import pandas as pd
import numpy as np
import scanpy as sc

# %%
#samples=["SMC01-T","SMC02-T","SMC04-T","SMC05-T","SMC07-T","SMC08-T","SMC09-T","SMC11-T","SMC14-T","SMC15-T","SMC16-T","SMC17-T","SMC18-T","SMC19-T","SMC20-T","SMC21-T","SMC22-T","SMC23-T","SMC25-T"]
samples=["SMC01-T","SMC02-T","SMC04-T","SMC07-T","SMC08-T","SMC09-T","SMC11-T","SMC14-T","SMC15-T","SMC16-T","SMC17-T","SMC18-T","SMC19-T","SMC20-T","SMC21-T","SMC22-T","SMC23-T","SMC25-T"]
# run also for N for a sanity check
#samples=["SMC01-N","SMC02-N","SMC04-N","SMC07-N","SMC08-N","SMC09-N"]#,"SMC11-N","SMC14-N","SMC15-N","SMC16-N","SMC17-N","SMC18-N","SMC19-N","SMC20-N","SMC21-N","SMC22-N","SMC23-N","SMC25-N"]
FOLDER='Scanpy_prova/count_matrix/GSE132465'

PRJ_ROOT='/mnt/cold1/snaketree/prj/scRNA'

# %%
dic_path={}
#filtered_annotated_saver_ribomito_CRC0322_NT_1_3000_log2_pc1_cpm.csv

for sample in samples:
    dic_path[sample]=PRJ_ROOT+'/dataset/'+FOLDER+'/'+sample+'_dir/annotated_'+sample+'_log2_pc1_cpm.csv'

# %%
dic_path
# Out:
# {'SMC01-T': '/mnt/cold1/snaketree/prj/scRNA/dataset/Scanpy_prova/count_matrix/GSE132465/SMC01-T_dir/annotated_SMC01-T_log2_pc1_cpm.csv',
#  'SMC02-T': '/mnt/cold1/snaketree/prj/scRNA/dataset/Scanpy_prova/count_matrix/GSE132465/SMC02-T_dir/annotated_SMC02-T_log2_pc1_cpm.csv',
#  'SMC04-T': '/mnt/cold1/snaketree/prj/scRNA/dataset/Scanpy_prova/count_matrix/GSE132465/SMC04-T_dir/annotated_SMC04-T_log2_pc1_cpm.csv',
#  'SMC07-T': '/mnt/cold1/snaketree/prj/scRNA/dataset/Scanpy_prova/count_matrix/GSE132465/SMC07-T_dir/annotated_SMC07-T_log2_pc1_cpm.csv',
#  'SMC08-T': '/mnt/cold1/snaketree/prj/scRNA/dataset/Scanpy_prova/count_matrix/GSE132465/SMC08-T_dir/annotated_SMC08-T_log2_pc1_cpm.csv',
#  'SMC09-T': '/mnt/cold1/snaketree/prj/scRNA/dataset/Scanpy_prova/count_matrix/GSE132465/SMC09-T_dir/annotated_SMC09-T_log2_pc1_cpm.csv',
#  'SMC11-T': '/mnt/cold1/snaketree/prj/scRNA/dataset/Scanpy_prova/count_matrix/GSE132465/SMC11-T_dir/annotated_SMC11-T_log2_pc1_cpm.csv',
#  'SMC14-T': '/mnt/cold1/snaketree/prj/scRNA/dataset/Scanpy_prova/count_matrix/GSE132465/SMC14-T_dir/annotated_SMC14-T_log2_pc1_cpm.csv',
#  'SMC15-T': '/mnt/cold1/snaketree/prj/scRNA/dataset/Scanpy_prova/count_matrix/GSE132465/SMC15-T_dir/annotated_SMC15-T_log2_pc1_cpm.csv',
#  'SMC16-T': '/mnt/cold1/snaketree/prj/scRNA/dataset/Scanpy_prova/count_matrix/GSE132465/SMC16-T_dir/annotated_SMC16-T_log2_pc1_cpm.csv',
#  'SMC17-T': '/mnt/cold1/snaketree/prj/scRNA/dataset/Scanpy_prova/count_matrix/GSE132465/SMC17-T_dir/annotated_SMC17-T_log2_pc1_cpm.csv',
#  'SMC18-T': '/mnt/cold1/snaketree/prj/scRNA/dataset/Scanpy_prova/count_matrix/GSE132465/SMC18-T_dir/annotated_SMC18-T_log2_pc1_cpm.csv',
#  'SMC19-T': '/mnt/cold1/snaketree/prj/scRNA/dataset/Scanpy_prova/count_matrix/GSE132465/SMC19-T_dir/annotated_SMC19-T_log2_pc1_cpm.csv',
#  'SMC20-T': '/mnt/cold1/snaketree/prj/scRNA/dataset/Scanpy_prova/count_matrix/GSE132465/SMC20-T_dir/annotated_SMC20-T_log2_pc1_cpm.csv',
#  'SMC21-T': '/mnt/cold1/snaketree/prj/scRNA/dataset/Scanpy_prova/count_matrix/GSE132465/SMC21-T_dir/annotated_SMC21-T_log2_pc1_cpm.csv',
#  'SMC22-T': '/mnt/cold1/snaketree/prj/scRNA/dataset/Scanpy_prova/count_matrix/GSE132465/SMC22-T_dir/annotated_SMC22-T_log2_pc1_cpm.csv',
#  'SMC23-T': '/mnt/cold1/snaketree/prj/scRNA/dataset/Scanpy_prova/count_matrix/GSE132465/SMC23-T_dir/annotated_SMC23-T_log2_pc1_cpm.csv',
#  'SMC25-T': '/mnt/cold1/snaketree/prj/scRNA/dataset/Scanpy_prova/count_matrix/GSE132465/SMC25-T_dir/annotated_SMC25-T_log2_pc1_cpm.csv'}

# %%
out_folder='GSE132465_GNN_vanilla'
with open("gene_list_n.txt", "r") as f:
    gene_list = [line.strip() for line in f if line.strip()]

# %%
len(gene_list)
# Out:
# 6000

# %%
import pandas as pd
import os

output_dir=out_folder
os.makedirs(output_dir, exist_ok=True)
geni_presenti={}

for sample_name, file_path in dic_path.items():
    print(f"Processing {sample_name}...")

    
    df = pd.read_csv(file_path,header=0,index_col=0,sep=',').T
    df.columns = [col.split(":")[1] if ":" in col else col for col in df.columns]

    selected_cols = [col for col in df.columns if col in gene_list]
    df_filtered = df[selected_cols]
    #geni_presenti[sample_name]=len(selected_cols)

    output_path = os.path.join(output_dir, f"filtered_{sample_name}.csv")
 
    df_filtered.to_csv(output_path)
print("Done!")
# Out:
# Processing SMC01-T...
# 123
# 1093
# Processing SMC02-T...
# 65
# 352
# Processing SMC04-T...
# 67
# 307
# Processing SMC07-T...
# 111
# 542
# Processing SMC08-T...
# 96
# 320
# Processing SMC09-T...
# 108
# 1887
# Processing SMC11-T...
# 91
# 326
# Processing SMC14-T...
# 40
# 166
# Processing SMC15-T...
# 32
# 319
# Processing SMC16-T...
# 125
# 2720
# Processing SMC17-T...
# 78
# 505
# Processing SMC18-T...
# 259
# 1516
# Processing SMC19-T...
# 33
# 382
# Processing SMC20-T...
# 99
# 524
# Processing SMC21-T...
# 179
# 1727
# Processing SMC22-T...
# 297
# 1902
# Processing SMC23-T...
# 53
# 639
# Processing SMC25-T...
# 69
# 416
# Done!

# %%
df_filtered.shape[0]
# Out:
# 1093

# %%
def n_alive(df, thr=1, wanted_genes=1000):
    n_alive = 0
    for cell_id, cell_expr in df_filtered.iterrows():
        expressed = cell_expr[cell_expr > thr]
        if len(expressed) > wanted_genes:
            n_alive = n_alive + 1

    return(n_alive)
